# %% [markdown]
# ## Welcome to Python Notebook
# ### Day 36
#
# This is where you can write your notes.

# %%
print("Kenma")
# Out:
# Kenma

# %%
for i in range(5):
    print(f"This value is {i}")
# Out:
# This value is 0
# This value is 1
# This value is 2
# This value is 3
# This value is 4
